# %%
import re
import string

# %%
def word_without_punctuation(lines):
    new_words = []  # this holds the values of the words without punctuation
    lines = lines.rstrip()  # this will get rid of any whitespace
    words = lines.split()  # this will hold the value of the words given in the parameter

    # this goes through the list of words and makes it lower case
    for word in words:
        new_words.append(word.strip(string.punctuation).lower())

    return new_words

# %%
def stopWords():
    new_stopwords = []
    stoplist = open('stopwords.txt', 'r', encoding='utf8')
    stopwords = stoplist.readlines()
    for word in stopwords:
        new_stopwords.append(word.rstrip())
    stoplist.close()
    return new_stopwords

# %%
def querySearch(indexDic):
    matches = False
    query=input('Please enter a query: ')
    querySplit = query.split()
    print("query= ", query)
    if query=="qquit":
        quit()

    elif len(querySplit) == 1:
        if querySplit[0] in indexDic.keys():
            for title, lNum in indexDic[query].items():
                print(title)
                for ln in lNum:
                    print(" ", ln, part2LineList[ln - 1].replace(query, "**" + query.upper() + "**"))
        else:
            print("- -")

    elif len(querySplit)==2:
        if querySplit[0] in indexDic.keys() and querySplit[1] in indexDic.keys():
            for title,lNum in indexDic[querySplit[0]].items():
                for title2, lNum2 in indexDic[querySplit[1]].items():
                    if title==title2:
                        matches=True
                        print(title)
                        print("   ", querySplit[0])
                        for ln in lNum:
                            print("     ", ln, part2LineList[ln - 1].replace(querySplit[0], "**" + querySplit[0].upper() + "**"))
                        print("   ", querySplit[1])
                        for ln2 in lNum2:
                            print("     ", ln2, part2LineList[ln2 - 1].replace(querySplit[1], "**" + querySplit[1].upper() + "**"))
        if matches==False:
            print("- -")

    elif len(querySplit) >= 3:
        if querySplit[1]=='or':
            if querySplit[0] in indexDic.keys():
                ## print(querySplit[0])
                for title, lNum in indexDic[querySplit[0]].items():
                    print(" ", title, "\n", querySplit[0])
                    for ln in lNum:
                        print("   ", ln, part2LineList[ln - 1].replace(querySplit[0], "**" + querySplit[0].upper() + "**"))

            else:
                print(querySplit[0], "\n", "- -")

            if querySplit[2] in indexDic.keys():
                #print(querySplit[2])
                for title, lNum in indexDic[querySplit[2]].items():
                    print(" ", title, "\n", querySplit[2])
                    for ln in lNum:
                        print("   ", ln, part2LineList[ln - 1].replace(querySplit[2], "**" + querySplit[2].upper() + "**"))
            else:
                print(querySplit[2], "\n", "- -")
        elif querySplit[1]=='and':
            if querySplit[0] in indexDic.keys() and querySplit[2] in indexDic.keys():
                for title, lNum in indexDic[querySplit[0]].items():
                    for title2, lNum2 in indexDic[querySplit[2]].items():
                        if title == title2:
                            matches = True
                            print(title)
                            print("   ", querySplit[0])
                            for ln in lNum:
                                print("     ", ln,part2LineList[ln - 1].replace(querySplit[0], "**" + querySplit[0].upper() + "**"))
                            print("   ", querySplit[2])
                            for ln2 in lNum2:
                                print("     ", ln2, part2LineList[ln2 - 1].replace(querySplit[2],"**" + querySplit[2].upper() + "**"))
            if matches == False:
                print("- -")


        elif querySplit[1]=='near':
            if querySplit[0] in indexDic.keys() and querySplit[2] in indexDic.keys():
                for title, lNum in indexDic[querySplit[0]].items():
                    for title2, lNum2 in indexDic[querySplit[2]].items():
                        if title == title2:
                            for ln in lNum:
                                for ln2 in lNum2:
                                    difference = 0
                                    difference = abs(ln - ln2)
                                    if difference<=1 and difference>=0:
                                        matches=True
                                        print(title)
                                        print("   ", querySplit[0])
                                        print("     ", ln, part2LineList[ln - 1].replace(querySplit[0],"**" + querySplit[0].upper() + "**"))
                                        print("   ", querySplit[2])
                                        print("     ", ln2, part2LineList[ln2 - 1].replace(querySplit[2],"**" + querySplit[2].upper() + "**"))


            if matches==False:
                print("- -")

        else:

            counter=0
            for words in querySplit:
                if words in indexDic.keys():
                    # match will be True if all the query words are in the dictionary
                    # counter counts how many words are in the query
                    matches=True
                    counter+=1
                else:
                    # if it is false the loop will break and the "if" statement below will not execute
                    matches=False
                    break

            if matches==True:
                titles=[]
                # for loop iterates through every word query
                for i in range(counter):
                    # for loop iterates through every title associated with query
                    for title in indexDic[querySplit[i]].keys():
                        # holds all the titles associated with the word query
                        titles.append(title)
                for x in titles:
                    # if the current title in the list appears the same amount of how many query words
                    # then every query word shares that title
                    if titles.count(x)==counter:
                        print("\n",x)
                        for i in range(counter):
                            print("  ", querySplit[i])
                            for lineNums in indexDic[querySplit[i]][x]:
                                integerLine=int(lineNums)
                                print("     ", integerLine,part2LineList[integerLine - 1].replace(querySplit[i], "**" + querySplit[i].upper() + "**"))
                        break
            else:
                print("- -")

    querySearch(indexDic)

# %%
if __name__ == '__main__':
    indexDic={}
    stopWordList= stopWords()
    grimmText = open('grimms.txt', 'r')
    lineNum=0
    part2LineList=[]
    for line in grimmText:
        lineNum += 1
        lines=line.strip()
        part2LineList.append(lines)

        matchTitle = re.search(r'^[A-Z\-\[ ]+-?[A-Z]$', line)
        if lineNum<401 or lineNum>9593:

            continue
        else:
            if matchTitle:
                cur_title=line.strip()

            else:
                newlineList = word_without_punctuation(line)
                for word in newlineList:
                    if word not in stopWordList:
                        indexDic.setdefault(word,{}).setdefault(cur_title,[]).append(lineNum)


    querySearch(indexDic)
# Out:
# Please enter a query: king AND queen
# query=  king AND queen
# - -
# Please enter a query: dog and cat
# query=  dog and cat
# THE TRAVELLING MUSICIANS
#     dog
#       945 After he had travelled a little way, he spied a **DOG** lying by the
#       947 friend?' said the ass. 'Alas!' said the **DOG**, 'my master was going to
#       952 can do in the same way?' The **DOG** said he was willing, and they jogged
#       981 night came on, they went into a wood to sleep. The ass and the **DOG**
#       991 **DOG**, 'I should not be the worse for a bone or two, or a bit of meat.'
#       1005 forefeet resting against the window; the **DOG** got upon his back; the
#       1008 began their music. The ass brayed, the **DOG** barked, the cat mewed, and
#       1020 heap of straw in the yard, the **DOG** stretched himself upon a mat behind
#       1035 him dreadfully, and away he ran to the back door; but there the **DOG**
#     cat
#       955 They had not gone far before they saw a **CAT** sitting in the middle of
#       958 me!' said the **CAT**, 'how can one be in good spirits when one's life is
#       965 musician.' The **CAT** was pleased with the thought, and joined the party.
#       982 laid themselves down under a great tree, and the **CAT** climbed up into
#       1006 **CAT** scrambled up to the dog's shoulders, and the cock flew up and sat
#       1008 began their music. The ass brayed, the dog barked, the **CAT** mewed, and
#       1021 the door, the **CAT** rolled herself up on the hearth before the warm
#       1032 fiery eyes of the **CAT**, he mistook them for live coals, and held the
#       1033 match to them to light it. But the **CAT**, not understanding this joke,
# OLD SULTAN
#     dog
#       1054 A shepherd had a faithful **DOG**, called Sultan, who was grown very old,
#       1079 The **DOG** liked this plan very well; and accordingly so it was managed.
#     cat
#       1103 old three-legged **CAT**; so he took her with him, and as the poor thing
#       1113 jumped up into a tree. Sultan and the **CAT** soon came up, and looked
#       1116 shook one of them a little, the **CAT**, seeing something move, and
# HANSEL AND GRETEL
#     dog
#       3253 across a **DOG** who, having met the sausage, had regarded him as his
#       3255 to the **DOG** of this bare-faced robbery, but nothing he said was of any
#       3256 avail, for the **DOG** answered that he found false credentials on the
#     cat
#       2995 at my little white **CAT**, which is sitting up on the roof, and wants to
#       2996 say goodbye to me.' The wife said: 'Fool, that is not your little **CAT**,
#       2998 however, had not been looking back at the **CAT**, but had been constantly
# LILY AND THE LION
#     dog
#       6755 'It may perhaps be only a cat or a **DOG**.' And at last the man yielded
#     cat
#       6755 'It may perhaps be only a **CAT** or a dog.' And at last the man yielded
# THE KING OF THE GOLDEN MOUNTAIN
#     dog
#       7845 great thing to ask; that it would most likely be his **DOG** or his cat,
#     cat
#       7845 great thing to ask; that it would most likely be his dog or his **CAT**,
# SECOND STORY
#     dog
#       8289 When the wolf was gone, came a **DOG**, a stag, a hare, a bear, a lion,
#     cat
#       8253 the door, and the **CAT** who was servant to Mrs Fox, opened it for him.
#       8256 'Good day, Mrs Cat of Kehrewit,
#       8260 The **CAT** replied:
#       8265 'No, thank you, Mrs Cat,' answered the wolf. 'Is Mrs Fox not at home?'
#       8267 The **CAT** said:
#       8278 The **CAT** runs quickly up the stair,
#       8287 pointed mouth?' 'No,' answered the **CAT**. 'Then he won't do for me.'
#       8292 the **CAT** had continually to send the suitors away. At length came a
#       8294 has a little pointed mouth?' 'Yes,' said the **CAT**, 'he has.' 'Then let
# Please enter a query: dog or cat
# query=  dog or cat
#   THE TRAVELLING MUSICIANS
#  dog
#     945 After he had travelled a little way, he spied a **DOG** lying by the
#     947 friend?' said the ass. 'Alas!' said the **DOG**, 'my master was going to
#     952 can do in the same way?' The **DOG** said he was willing, and they jogged
#     981 night came on, they went into a wood to sleep. The ass and the **DOG**
#     991 **DOG**, 'I should not be the worse for a bone or two, or a bit of meat.'
#     1005 forefeet resting against the window; the **DOG** got upon his back; the
#     1008 began their music. The ass brayed, the **DOG** barked, the cat mewed, and
#     1020 heap of straw in the yard, the **DOG** stretched himself upon a mat behind
#     1035 him dreadfully, and away he ran to the back door; but there the **DOG**
#   OLD SULTAN
#  dog
#     1054 A shepherd had a faithful **DOG**, called Sultan, who was grown very old,
#     1079 The **DOG** liked this plan very well; and accordingly so it was managed.
#   THE DOG AND THE SPARROW
#  dog
#     1309 A shepherd's **DOG** had a master who took no care of him, but often let
#     1313 friend?' 'Because,' said the **DOG**, 'I am very very hungry, and have
#     1317 shop, the sparrow said to the **DOG**, 'Stand there a little while till I
#     1321 edge of the shelf, till at last down it fell. Then the **DOG** snapped it
#     1325 steak.' When the **DOG** had eaten this too, the sparrow said to him,
#     1330 rolls that lay in the window, till they fell down: and as the **DOG**
#     1335 but as the weather was warm, they had not gone far before the **DOG**
#     1338 upon that bush.' So the **DOG** stretched himself out on the road, and
#     1342 the track in which the **DOG** lay, so as to drive over him, called out,
#     1346 **DOG**, so that the wheels crushed him to death. 'There,' cried the
#     1347 sparrow, 'thou cruel villain, thou hast killed my friend the **DOG**. Now
#   HANSEL AND GRETEL
#  dog
#     3253 across a **DOG** who, having met the sausage, had regarded him as his
#     3255 to the **DOG** of this bare-faced robbery, but nothing he said was of any
#     3256 avail, for the **DOG** answered that he found false credentials on the
#   FREDERICK AND CATHERINE
#  dog
#     4360 last it popped into her head, 'The **DOG** is not shut up--he may be
#     4365 Away ran Catherine, and away ran the **DOG** across the field: but he ran
#     4389 while I went down to draw the ale, the **DOG** ran away with it; and while
#   THE PINK
#  dog
#     4930 into a poodle **DOG**, and had a gold collar round his neck, and the cooks
#     4980 apron with the blood of a chicken.' Thereupon he took the **DOG** with the
#     4982 to be brought, and these the **DOG** was compelled to devour before the
#     4984 huntsman asked the king if he would like to see the **DOG** in his true
#   LILY AND THE LION
#  dog
#     6755 'It may perhaps be only a cat or a **DOG**.' And at last the man yielded
#   THE KING OF THE GOLDEN MOUNTAIN
#  dog
#     7845 great thing to ask; that it would most likely be his **DOG** or his cat,
#   SECOND STORY
#  dog
#     8289 When the wolf was gone, came a **DOG**, a stag, a hare, a bear, a lion,
#   IRON HANS
#  dog
#     8954 The huntsman therefore betook himself with his **DOG** to the forest. It
#     8955 was not long before the **DOG** fell in with some game on the way, and
#     8956 wanted to pursue it; but hardly had the **DOG** run two steps when it
#   SNOW-WHITE AND ROSE-RED
#  dog
#     9487 **DOG** tied to a rope, and did not know what to do.
#   JORINDA AND JORINDEL
#  cat
#     822 the form of an owl, or crept about the country like a **CAT**; but at
#   THE TRAVELLING MUSICIANS
#  cat
#     955 They had not gone far before they saw a **CAT** sitting in the middle of
#     958 me!' said the **CAT**, 'how can one be in good spirits when one's life is
#     965 musician.' The **CAT** was pleased with the thought, and joined the party.
#     982 laid themselves down under a great tree, and the **CAT** climbed up into
#     1006 **CAT** scrambled up to the dog's shoulders, and the cock flew up and sat
#     1008 began their music. The ass brayed, the dog barked, the **CAT** mewed, and
#     1021 the door, the **CAT** rolled herself up on the hearth before the warm
#     1032 fiery eyes of the **CAT**, he mistook them for live coals, and held the
#     1033 match to them to light it. But the **CAT**, not understanding this joke,
#   OLD SULTAN
#  cat
#     1103 old three-legged **CAT**; so he took her with him, and as the poor thing
#     1113 jumped up into a tree. Sultan and the **CAT** soon came up, and looked
#     1116 shook one of them a little, the **CAT**, seeing something move, and
#   CAT AND MOUSE IN PARTNERSHIP
#  cat
#     1964 A certain **CAT** had made the acquaintance of a mouse, and had said so
#     1968 suffer from hunger,' said the **CAT**; 'and you, little mouse, cannot
#     1971 not know where to put it. At length, after much consideration, the **CAT**
#     1976 **CAT** had a great yearning for it, and said to the mouse: 'I want to
#     1983 christening wine myself.' All this, however, was untrue; the **CAT** had
#     1991 off well,' answered the **CAT**. 'What name did they give the child?' 'Top
#     1992 off!' said the **CAT** quite coolly. 'Top off!' cried the mouse, 'that is
#     1994 does that matter,' said the **CAT**, 'it is no worse than Crumb-stealer,
#     1997 Before long the **CAT** was seized by another fit of yearning. She said to
#     2001 consented, but the **CAT** crept behind the town walls to the church, and
#     2005 christened?' 'Half-done,' answered the **CAT**. 'Half-done! What are you
#     2015 make me very thoughtful.' 'You sit at home,' said the **CAT**, 'in your
#     2018 the mouse cleaned the house, and put it in order, but the greedy **CAT**
#     2023 others,' said the **CAT**. 'He is called All-gone.' 'All-gone,' cried the
#     2028 From this time forth no one invited the **CAT** to be godmother, but when
#     2030 outside, the mouse thought of their provision, and said: 'Come, **CAT**,
#     2032 shall enjoy that.' 'Yes,' answered the **CAT**, 'you will enjoy it as much
#     2039 cried the **CAT**, 'one word more, and I will eat you too.' 'All-gone' was
#     2041 the **CAT** sprang on her, seized her, and swallowed her down. Verily,
#   THE ADVENTURES OF CHANTICLEER AND PARTLET
#  cat
#     2366 carriage, and away they drove. Soon afterwards a **CAT** met them, and
#     2373 Then the **CAT** said, 'Take me with you,' Chanticleer said, 'With all my
#     2389 flew upon a beam, the **CAT** sat down in the fireplace, the duck got into
#     2395 the **CAT** threw all the ashes in his eyes: so he ran to the kitchen to
#   RAPUNZEL
#  cat
#     2576 the nest; the **CAT** has got it, and will scratch out your eyes as well.
#   HANSEL AND GRETEL
#  cat
#     2995 at my little white **CAT**, which is sitting up on the roof, and wants to
#     2996 say goodbye to me.' The wife said: 'Fool, that is not your little **CAT**,
#     2998 however, had not been looking back at the **CAT**, but had been constantly
#   THE FOX AND THE CAT
#  cat
#     6551 It happened that the **CAT** met the fox in a forest, and as she thought
#     6556 **CAT** from head to foot, and for a long time did not know whether he
#     6561 one,' replied the **CAT**, modestly. 'What art is that?' asked the fox.
#     6566 hounds.' Just then came a hunter with four dogs. The **CAT** sprang nimbly
#     6569 cried the **CAT** to him, but the dogs had already seized him, and were
#     6570 holding him fast. 'Ah, Mr Fox,' cried the **CAT**. 'You with your hundred
#   LILY AND THE LION
#  cat
#     6755 'It may perhaps be only a **CAT** or a dog.' And at last the man yielded
#   THE KING OF THE GOLDEN MOUNTAIN
#  cat
#     7845 great thing to ask; that it would most likely be his dog or his **CAT**,
#   FIRST STORY
#  cat
#     8197 shut herself in, and her maid, Miss Cat, sat by the fire, and did the
#     8203 'What may you be about, Miss Cat?
#     8224 The **CAT** goes up the stairs trip, trap,
#     8227 'Oh, yes, my little **CAT**,' she cried.
#     8232 answered the **CAT**, 'he has only one.' 'Then I will not have him.'
#     8234 Miss Cat went downstairs and sent the wooer away. Soon afterwards
#     8240 joyfully to the **CAT**:
#   SECOND STORY
#  cat
#     8253 the door, and the **CAT** who was servant to Mrs Fox, opened it for him.
#     8256 'Good day, Mrs Cat of Kehrewit,
#     8260 The **CAT** replied:
#     8265 'No, thank you, Mrs Cat,' answered the wolf. 'Is Mrs Fox not at home?'
#     8267 The **CAT** said:
#     8278 The **CAT** runs quickly up the stair,
#     8287 pointed mouth?' 'No,' answered the **CAT**. 'Then he won't do for me.'
#     8292 the **CAT** had continually to send the suitors away. At length came a
#     8294 has a little pointed mouth?' 'Yes,' said the **CAT**, 'he has.' 'Then let
#   CAT-SKIN
#  cat
#     9287 blackened her face and hands, put on the fur-skin cloak, and was Cat-
#     9336 time, it happened just the same as before. 'You must be a witch, Cat-
# Please enter a query: dog cat queen
# query=  dog cat queen
#
#  THE KING OF THE GOLDEN MOUNTAIN
#    dog
#       7845 great thing to ask; that it would most likely be his **DOG** or his cat,
#    cat
#       7845 great thing to ask; that it would most likely be his dog or his **CAT**,
#    queen
#       7939 They lived together very happily, and the **QUEEN** had a son. And thus
#       7941 father; and he began to long to see him once again. But the **QUEEN** was
#       7968 his word, turned his ring, and wished for his **QUEEN** and son. In an
#       7969 instant they stood before him; but the **QUEEN** wept, and said he had
#       8003 the people around told him that his **QUEEN** was about to marry another
#       8005 castle hall, and placed himself by the side of the **QUEEN**, where no one
# Please enter a query: king
# query=  king
# THE GOLDEN BIRD
#   403 A certain **KING** had a beautiful garden, and in the garden stood a tree
#   406 one of them was gone. The **KING** became very angry at this, and ordered
#   419 and then flew away. The golden feather was brought to the **KING** in the
#   421 it was worth more than all the wealth of the **KING**dom: but the **KING**
#   484 awoke, and they took him prisoner and carried him before the **KING**. The
#   486 sentenced him to die, unless he should bring the **KING** the golden horse
#   530 Then he was brought before the **KING**, and the **KING** said, 'You shall
#   530 Then he was brought before the **KING**, and the **KING** said, 'You shall
#   536 hill was gone; so he went merrily to the **KING**, and told him that now
#   539 Then the **KING** was obliged to keep his word, and away went the young
#   545 come to the **KING**, and he asks for the beautiful princess, you must
#   554 ride in and speak to the **KING**; and when he sees that it is the right
#   584 went home to the **KING** their master, and said. 'All this have we won by
#   598 sing, and princess left off weeping. Then he went to the **KING**, and
# BRIAR ROSE
#   1178 A **KING** and queen once upon a time reigned in a country a great way
#   1179 off, where there were in those days fairies. Now this **KING** and queen
#   1192 beautiful that the **KING** could not cease loo**KING** on it for joy, and
#   1197 thirteen fairies in the **KING**dom; but as the **KING** and queen had only
#   2248 hair. All this the old **KING** saw: so he went home without being seen;
#   2253 But the old **KING** begged so hard, that she had no peace till she had
#   2255 was very lucky for her that she did so, for when she had done the **KING**
#   2259 while the true bride stood by. And the young **KING** rejoiced when he saw
#   2261 saying anything to the false bride, the **KING** ordered a great feast to
#   2268 When they had eaten and drank, and were very merry, the old **KING** said
#   2276 **KING**; 'and as thou has judged thyself, so shall it be done to thee.'
#   2277 And the young **KING** was then married to his true wife, and they reigned
# THE VALIANT LITTLE TAILOR
#   2804 be a mighty lord.' They went and announced him to the **KING**, and gave
#   2807 depart. The counsel pleased the **KING**, and he sent one of his courtiers
#   2820 to the **KING**, and begged for their dismissal. 'We are not prepared,'
#   2822 **KING** was sorry that for the sake of one he should lose all his
#   2880 The little tailor demanded of the **KING** the promised reward; he,
#   2899 to the **KING**.
#   2901 The **KING** still would not give him the promised reward, and made a
#   2916 The hero, however, went to the **KING**, who was now, whether he liked it
#   2921 magnificence and small joy, and out of a tailor a **KING** was made.
#   2928 get rid of her husband, who was nothing else but a tailor. The **KING**
#   2946 him. So the little tailor was and remained a **KING** to the end of his
# RUMPELSTILTSKIN
#   3953 was so proud of her, that he one day told the **KING** of the land, who
#   3955 out of straw. Now this **KING** was very fond of money; and when he heard
#   3981 When the **KING** came and saw this, he was greatly astonished and
#   3996 The **KING** was greatly delighted to see all this glittering treasure;
#   4006 manikin once more spun the heap into gold. The **KING** came in the
# SNOWDROP
#   4650 But this queen died; and the **KING** soon married another wife, who
# THE PINK
#   4878 have.' Then she went to the **KING**, and told him the joyful tidings, and
#   4879 when the time was come she gave birth to a son, and the **KING** was
#   4890 the **KING** and accused the queen of having allowed her child to be taken
#   4891 from her by the wild beasts. When the **KING** saw the blood on her apron,
#   4950 offer him service. The **KING** said yes, if he was skilful and could get
#   4959 all placed on sixty country carts, and driven home to the **KING**, and
#   4963 Now the **KING** felt great joy at this, and commanded that his entire
#   4966 so clever, you shall sit by me.' He replied: 'Lord King, your majesty
#   4967 must excuse me, I am a poor huntsman.' But the **KING** insisted on it,
#   4975 died?' But the **KING** replied: 'She let my dear son be torn to pieces by
#   4984 huntsman asked the **KING** if he would like to see the dog in his true
#   4987 When the **KING** saw him he fell into a passion, and ordered him to be
#   4991 life depended on it?' The **KING** replied: 'Yes, I would like to see
#   4995 and it was so beautiful that the **KING** had never seen one to equal it.
#   5000 And the **KING** sent two waiting-maids and two attendants into the tower,
#   5007 aged **KING** ordered the cook to be torn in four pieces, but grief
# ASHPUTTEL
#   5265 Now it happened that the **KING** of that land held a feast, which was to
#   5409 The prince took the shoe, and went the next day to the **KING** his
# THE WHITE SNAKE
#   5478 A long time ago there lived a **KING** who was famed for his wisdom
#   5484 not know what was in it, neither did anyone know, for the **KING** never
#   5502 trusty servant, who was allowed to go everywhere. The **KING** ordered the
#   5524 The servant could now easily prove his innocence; and the **KING**, to
#   5563 forgot all danger, went before the **KING**, and declared himself a
#   8832 the **KING** said, 'You have sung so well, that I will give you my
#   8833 daughter for your wife.' The princess begged and prayed; but the **KING**
#   8836 and she was married to the fiddler. When this was over the **KING** said,
#   8842 belongs to King Grisly-beard,' answered he; 'hadst thou taken him, all
#   8844 that I had married King Grisly-beard!' Next they came to some fine
#   8846 belong to King Grisly-beard, hadst thou taken him, they had all been
#   8848 married King Grisly-beard!'
#   8851 'It belongs to King Grisly-beard; hadst thou taken him, it had all
#   8853 King Grisly-beard?' 'That is no business of mine,' said the fiddler:
#   8912 she trembled for fear, for she saw that it was King Grisly-beard, who
#   8917 She sprang to the door to run away; but on the steps King Grisly-beard
# IRON HANS
#   8935 There was once upon a time a **KING** who had a great forest near his
#   8938 accident has befallen him,' said the **KING**, and the next day he sent
#   8947 himself to the **KING** as see**KING** a situation, and offered to go into the
#   8948 dangerous forest. The **KING**, however, would not give his consent, and
#   8964 wild man; the **KING**, however, had him put in an iron cage in his
#   8969 The **KING** had a son of eight years, who was once playing in the
#   8973 boy, 'I will not do that; the **KING** has forbidden it,' and ran away.
#   8975 'Open my door,' but the boy would not. On the third day the **KING** had
#   8985 his shoulder, and went with hasty steps into the forest. When the **KING**
#   8988 was gone. She called the boy, but no one answered. The **KING** sent out
#   9054 cannot; I have a bad sore place on my head.' Then the **KING** had the
#   9090 Not long afterwards, the country was overrun by war. The **KING** gathered
#   9115 man left. Instead of returning to the **KING**, however, he conducted his
#   9120 **KING** returned to his palace, his daughter went to meet him, and wished
#   9124 was, but the **KING** did not know, and said: 'He followed the enemy, and
#   9133 The **KING** said to his daughter: 'I will proclaim a great feast that
#   9148 he did not linger an instant, but galloped off with it. The **KING** grew
#   9161 to the **KING**.
#   9168 The **KING** had him summoned into his presence, and he came and again had
#   9173 caught the three golden apples?' asked the **KING**. 'Yes,' answered he,
#   9175 returned them to the **KING**. 'If you desire further proof, you may see
#   9179 tell me, who is your father?' 'My father is a mighty **KING**, and gold
#   9180 have I in plenty as great as I require.' 'I well see,' said the **KING**,
#   9189 stately **KING** came in with a great retinue. He went up to the youth,
# CAT-SKIN
#   9198 There was once a **KING**, whose queen had hair of the purest gold, and
#   9201 felt that her end drew near she called the **KING** to her and said,
#   9204 Then when the **KING** in his grief promised all she asked, she shut her
#   9205 eyes and died. But the **KING** was not to be comforted, and for a long
#   9207 men said, 'this will not do; the **KING** must marry again, that we may
#   9214 Now the **KING** had a daughter, who was just as beautiful as her mother,
#   9215 and had the same golden hair. And when she was grown up, the **KING**
#   9222 come.' And his daughter was also shocked, but hoped the **KING** would
#   9229 matter no more. But the **KING** made the most skilful workmen in his
#   9236 When all were ready, the **KING** sent them to her; but she got up in the
#   9247 Now as the **KING** to whom the wood belonged was hunting in it, his dogs
#   9249 and bark. 'Look sharp!' said the **KING** to the huntsmen, 'and see what
#   9254 the **KING**, 'if you can catch it alive, and we will take it with us.' So
#   9279 no less than a **KING**'s daughter. But the **KING** came up to her, and held
#   9283 When the dance was at an end she curtsied; and when the **KING** looked
#   9298 was over, the **KING** ordered his soup to be brought in; and it pleased
#   9304 beating.' Then he went before the **KING**, and he asked him who had
#   9305 cooked the soup. 'I did,' answered the cook. But the **KING** said, 'That
#   9308 'Then let Cat-skin come up,' said the **KING**: and when she came he said
#   9313 was in the soup?' asked the **KING**. Then she would not own that she knew
#   9314 anything about the ring; so the **KING** sent her away again about her
#   9319 half an hour, and cook the **KING** the soup that he likes so much.' Then
#   9322 went in, loo**KING** like a **KING**'s daughter, the **KING** went up to her, and
#   9325 that the **KING** did not see where she was gone; but she sprang into her
#   9329 to the **KING**, who ate it, and it pleased him as well as before; so he
#   9331 cooked it. Cat-skin was brought again before the **KING**, but she still
#   9335 But when the **KING** had ordered a feast to be got ready for the third
#   9338 that it pleases the **KING** better than mine.' However, he let her go up
#   9340 and went into the ball-room in it; and the **KING** danced with her again,
#   9354 the **KING** got to the bottom, he ordered Cat-skin to be called once
#   9364 most beautiful princess upon the face of the earth. But the **KING** said,
# Please enter a query: frog king queen
# query=  frog king queen
# Please enter a query: dog cat queen
# query=  dog cat queen
#
#  THE KING OF THE GOLDEN MOUNTAIN
#    dog
#       7845 great thing to ask; that it would most likely be his **DOG** or his cat,
#    cat
#       7845 great thing to ask; that it would most likely be his dog or his **CAT**,
#    queen
#       7939 They lived together very happily, and the **QUEEN** had a son. And thus
#       7941 father; and he began to long to see him once again. But the **QUEEN** was
#       7968 his word, turned his ring, and wished for his **QUEEN** and son. In an
#       7969 instant they stood before him; but the **QUEEN** wept, and said he had
#       8003 the people around told him that his **QUEEN** was about to marry another
#       8005 castle hall, and placed himself by the side of the **QUEEN**, where no one
# Please enter a query: queen king and dog
# query=  queen king and dog
# - -
# Please enter a query: cat near dog
# query=  cat near dog
# THE TRAVELLING MUSICIANS
#     cat
#       982 laid themselves down under a great tree, and the **CAT** climbed up into
#     dog
#       981 night came on, they went into a wood to sleep. The ass and the **DOG**
# THE TRAVELLING MUSICIANS
#     cat
#       1006 **CAT** scrambled up to the dog's shoulders, and the cock flew up and sat
#     dog
#       1005 forefeet resting against the window; the **DOG** got upon his back; the
# THE TRAVELLING MUSICIANS
#     cat
#       1008 began their music. The ass brayed, the dog barked, the **CAT** mewed, and
#     dog
#       1008 began their music. The ass brayed, the **DOG** barked, the cat mewed, and
# THE TRAVELLING MUSICIANS
#     cat
#       1021 the door, the **CAT** rolled herself up on the hearth before the warm
#     dog
#       1020 heap of straw in the yard, the **DOG** stretched himself upon a mat behind
# LILY AND THE LION
#     cat
#       6755 'It may perhaps be only a **CAT** or a dog.' And at last the man yielded
#     dog
#       6755 'It may perhaps be only a cat or a **DOG**.' And at last the man yielded
# THE KING OF THE GOLDEN MOUNTAIN
#     cat
#       7845 great thing to ask; that it would most likely be his dog or his **CAT**,
#     dog
#       7845 great thing to ask; that it would most likely be his **DOG** or his cat,
